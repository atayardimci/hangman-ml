# %%
# # Run this notebook on Colab with T4 GPU

# import tensorflow as tf
# tf.config.list_physical_devices('GPU')

# from google.colab import drive
# drive.mount("/content/drive")

# DATA_FOLDER = "/content/drive/My Drive/Data/"

# %%
DATA_FOLDER = "./data/"

# %%
import numpy as np
from keras import regularizers
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM, Dense, Masking, Dropout, Bidirectional, Input, Concatenate
from keras.models import Model

from typing import Any

import h5py

import cProfile

# %%
FILENAME_TRAIN= f"{DATA_FOLDER}train_data_post.h5"
with h5py.File(FILENAME_TRAIN, 'r') as hf:
    X_train_masked_words = hf["masked_words"]
    X_train_guesses = hf["previous_guesses"]
    y_train = hf['next_guess_probs']

    assert X_train_masked_words.shape[0] == X_train_guesses.shape[0] == y_train.shape[0]
    LEN_TRAIN = y_train.shape[0]
    print(f"Number of training samples and labels: {LEN_TRAIN}")


FILENAME_VAL= f"{DATA_FOLDER}validation_data_post.h5"
with h5py.File(FILENAME_VAL, 'r') as hf:
    X_val_masked_words = hf["masked_words"]
    X_val_guesses = hf["previous_guesses"]
    y_val = hf['next_guess_probs']

    assert X_val_masked_words.shape[0] == X_val_guesses.shape[0] == y_val.shape[0]
    LEN_VAL = y_val.shape[0]
    print(f"Number of validation samples and labels: {LEN_VAL}")
# Out:
# Number of training samples and labels: 7665680
# Number of validation samples and labels: 1912161

# %% [markdown]
# ## Build the model

# %%
def generate_samples_and_labels(filename: str, batch_size: int):
    with h5py.File(filename, 'r') as hf:
        X_masked_words = hf['masked_words']
        X_guesses = hf['previous_guesses']
        y = hf['next_guess_probs']

        for i in range(0, y.shape[0], batch_size):
            batch_X_masked_words = X_masked_words[i:i + batch_size]
            batch_X_guesses = X_guesses[i:i + batch_size]
            batch_y = y[i:i + batch_size]

            yield (batch_X_masked_words, batch_X_guesses), batch_y

# %%
def build_hangman_model(max_word_len: int, alphabet_len: int):
    alphabet_len_with_mask = alphabet_len + 1

    # Define input layers for masked word and guessed letters
    hidden_word_input = Input(
        shape=(max_word_len, alphabet_len_with_mask), name="hidden_word_input"
    )
    guessed_letters_input = Input(shape=(alphabet_len,), name="guessed_letters_input")

    hidden_word_input_masked = Masking(mask_value=-1)(hidden_word_input)

    # LSTM layer to process the hidden word
    lstm_output = Bidirectional(LSTM(128))(hidden_word_input_masked)
    lstm_dropout = Dropout(0.1)(lstm_output)

    # Concatenate LSTM output with guessed letters
    combined_input = Concatenate()([lstm_dropout, guessed_letters_input])

    # Dense layer
    dense_output = Dense(
        64,
        activation="relu",
        kernel_regularizer=regularizers.l2(0.01)
    )(combined_input)
    dense_dropout = Dropout(0.1)(dense_output)

    # Output layer
    output = Dense(alphabet_len, activation="softmax", name="output")(dense_dropout)

    # Define model with inputs and output
    model = Model(inputs=[hidden_word_input, guessed_letters_input], outputs=output)

    return model

# %%
MAX_WORD_LEN = 30
ALPHABET_LEN = 26

# Build the model
model = build_hangman_model(MAX_WORD_LEN, ALPHABET_LEN)

# Load previous weights
# model_weights = f"{DATA_FOLDER}hangman_model.weights.h5"
# model.load_weights(model_weights)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ hidden_word_input   │ (None, 30, 27)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, 30, 27)    │          0 │ hidden_word_inpu… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking (Masking)   │ (None, 30, 27)    │          0 │ hidden_word_inpu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any (Any)           │ (None, 30)        │          0 │ not_equal[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 256)       │    159,744 │ masking[0][0],    │
# │ (Bidirectional)     │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ bidirectional[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ guessed_letters_in… │ (None, 26)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 282)       │          0 │ dropout[0][0],    │
# │ (Concatenate)       │                   │            │ guessed_letters_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │     18,112 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 26)        │      1,690 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 179,546 (701.35 KB)
#  Trainable params: 179,546 (701.35 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

early_stopping = EarlyStopping(monitor="val_loss", patience=2, verbose=1, restore_best_weights=True)
checkpoint_callback = ModelCheckpoint(
    filepath=f"{DATA_FOLDER}hangman_model.weights.h5",
    save_weights_only=True,
    save_best_only=True
)

epochs = 4
batch_size = 64

for _ in range(epochs):
    train_generator = generate_samples_and_labels(FILENAME_TRAIN, batch_size)
    val_generator = generate_samples_and_labels(FILENAME_VAL, batch_size)

    history = model.fit(
        train_generator,
        steps_per_epoch=LEN_TRAIN // batch_size,
        epochs=1,
        validation_data=val_generator,
        validation_steps=LEN_VAL // batch_size,
        callbacks=[early_stopping, checkpoint_callback],
    )

model.save(f"{DATA_FOLDER}hangman_model.keras")

# %% [markdown]
# ## Predictions

# %%
# Load the model

hangman_model = build_hangman_model(MAX_WORD_LEN, ALPHABET_LEN)
weights = f"{DATA_FOLDER}hangman_model.weights.h5"
hangman_model.load_weights(weights)

# %%
# Necessary imports and data structures for making predictions

import collections
from keras.preprocessing.sequence import pad_sequences

from utils.samples_and_labels import (
    CHAR_TO_IDX,
    IDX_TO_CHAR,
    build_len_to_most_frequent_letters,
    build_len_to_words_trie,
    find_matching_words_in_trie,
    sample_from_masked_word_and_guesses,
)
from utils.trie import Trie


# Load the dictionary
dictionary_file_location = "./data/words_250000_train.txt"
text_file = open(dictionary_file_location, "r")
full_dictionary = text_file.read().splitlines()
text_file.close()

LEN_TO_MOST_FREQUENT_LETTERS = build_len_to_most_frequent_letters(full_dictionary)
LEN_TO_WORDS_TRIE = build_len_to_words_trie(full_dictionary)

# %%
# Function to predict the next letter

def get_next_letter_probs_with_model(masked_word: str, guesses: set[str], model: Any) -> np.ndarray:
    """Get the probabilities of the next letter given the masked word and guesses."""
    masked_word_encoding, guesses_encoding = sample_from_masked_word_and_guesses(masked_word, guesses)

    masked_word_sample = pad_sequences([masked_word_encoding], maxlen=MAX_WORD_LEN, padding='post', value=-1)
    guesses_sample = np.array([guesses_encoding])

    prediction_vector = model.predict([masked_word_sample, guesses_sample], verbose=0)[0]
    return prediction_vector


def get_next_letter_from_trie(masked_word: str, incorrect_guesses: set[str], len_to_words_trie: dict[int, Trie]) -> str:
    """Get the next letter using the trie. Check for similar length words in the trie that do not contain incorrect guesses."""
    all_matching_words = []
    for len_to_check in range(len(masked_word) - 1, len(masked_word) + 2):
        if len_to_check not in len_to_words_trie:
            continue
        pattern = "".join("_" for _ in range(len_to_check))
        matching_words = find_matching_words_in_trie(pattern, incorrect_guesses, len_to_words_trie)
        all_matching_words.extend(matching_words)

    matching_words_full_str = "".join(all_matching_words)
    counter = collections.Counter(matching_words_full_str).most_common()

    for char, _ in counter:
        if char not in incorrect_guesses and char not in masked_word:
            return char


def predict_next_letter(masked_word: str, guesses: set[str], model: Any) -> tuple[str, np.ndarray | None]:
    """Predict the next letter given the masked word and guesses using the given model"""
    correct_guesses = set(masked_word) - {"_"}
    incorrect_guesses = guesses - correct_guesses

    percentage_of_unknown = masked_word.count("_") / len(masked_word)

    # If there are less than 2 correct guesses, use the trie to predict the next letter
    # Check for same length words in the trie that do not contain incorrect guesses
    if len(correct_guesses) < 1 or percentage_of_unknown > 0.75 and len(correct_guesses) < 2:
        next_letter = get_next_letter_from_trie(masked_word, incorrect_guesses, LEN_TO_WORDS_TRIE)
        return next_letter, None

    # Predict the next letter using the model
    prediction_vector = get_next_letter_probs_with_model(masked_word, guesses, model)

    # Set probabilities of guessed letters to 0
    prediction_vector[[CHAR_TO_IDX[char] for char in guesses]] = 0

    if sum(prediction_vector) == 0:
        print("No valid predictions left. Guessing the most frequent letter")
        for char, _ in LEN_TO_MOST_FREQUENT_LETTERS[len(masked_word)]:
            if char not in guesses:
                return char, None

    predicted_letter = IDX_TO_CHAR[np.argmax(prediction_vector)]
    return predicted_letter, prediction_vector

# %% [markdown]
# ## Play

# %%
import random
from sklearn.model_selection import train_test_split

words_train, words_val = train_test_split(full_dictionary, test_size=0.2, random_state=42)
print(f"Number of words_train: {len(words_train)}")
print(f"Number of words_val: {len(words_val)}")
# Out:
# Number of words_train: 181840
# Number of words_val: 45460

# %%
# Test the model by playing hangman

# word_list = full_dictionary
# word_list = words_train
word_list = words_val

success_count = 0
total_games = 100

for i in range(total_games):
    word = random.choice(full_dictionary)
    print(f"GAME {i+1}: {word}")

    masked_word = ["_"] * len(word)
    guesses = set()
    incorrect_guesses = set()

    word_chars = set(word)

    while "_" in masked_word and len(incorrect_guesses) < 6:
        letter, _ = predict_next_letter(
            masked_word,
            guesses,
            hangman_model
        )
        guesses.add(letter)
        print(f"{letter}", end=": ")

        if letter in word_chars:
            for j, char in enumerate(word):
                if char == letter:
                    masked_word[j] = letter
        else:
            incorrect_guesses.add(letter)
        print("".join(masked_word))

    success = "_" not in masked_word
    print('SUCCESS' if success else 'FAILURE')

    if success:
        success_count += 1

print("Success rate:", success_count/total_games)
# Out:
# GAME 1: ensheathed
# e: e___e___e_
# r: e___e___e_
# d: e___e___ed
# t: e___e_t_ed
# h: e__he_thed
# a: e__heathed
# s: e_sheathed
# n: ensheathed
# SUCCESS
# GAME 2: jamaal
# e: ______
# a: _a_aa_
# l: _a_aal
# r: _a_aal
# n: _a_aal
# b: _a_aal
# t: _a_aal
# c: _a_aal
# FAILURE
# GAME 3: angka
# e: _____
# a: a___a
# r: a___a
# n: an__a
# t: an__a
# d: an__a
# g: ang_a
# i: ang_a
# l: ang_a
# FAILURE
# GAME 4: fredia
# e: __e___
# a: __e__a
# r: _re__a
# s: _re__a
# t: _re__a
# n: _re__a
# p: _re__a
# c: _re__a
# d: _red_a
# i: _redia
# o: _redia
# FAILURE
# GAME 5: possessival
# e: ____e______
# i: ____e__i___
# n: ____e__i___
# r: ____e__i___
# t: ____e__i___
# s: __ssessi___
# o: _ossessi___
# p: possessi___
# v: possessiv__
# a: possessiva_
# l: possessival
# SUCCESS
# GAME 6: boisseau
# e: _____e__
# a: _____ea_
# r: _____ea_
# l: _____ea_
# n: _____ea_
# t: _____ea_
# d: _____ea_
# b: b____ea_
# h: b____ea_
# FAILURE
# GAME 7: sorriness
# e: ______e__
# i: ____i_e__
# n: ____ine__
# s: s___iness
# l: s___iness
# r: s_rriness
# u: s_rriness
# a: s_rriness
# o: sorriness
# SUCCESS
# GAME 8: whitishflowered
# e: ___________e_e_
# i: __i_i______e_e_
# n: __i_i______e_e_
# r: __i_i______ere_
# d: __i_i______ered
# t: __iti______ered
# h: _hiti_h____ered
# c: _hiti_h____ered
# p: _hiti_h____ered
# s: _hitish____ered
# w: whitish___wered
# o: whitish__owered
# l: whitish_lowered
# f: whitishflowered
# SUCCESS
# GAME 9: snafflebridled
# e: ______e_____e_
# i: ______e__i__e_
# r: ______e_ri__e_
# t: ______e_ri__e_
# a: __a___e_ri__e_
# u: __a___e_ri__e_
# b: __a___ebri__e_
# n: _na___ebri__e_
# s: sna___ebri__e_
# l: sna__lebri_le_
# o: sna__lebri_le_
# c: sna__lebri_le_
# p: sna__lebri_le_
# d: sna__lebridled
# g: sna__lebridled
# FAILURE
# GAME 10: tribunitiary
# e: ____________
# i: __i___i_i___
# n: __i__ni_i___
# t: t_i__niti___
# o: t_i__niti___
# a: t_i__nitia__
# l: t_i__nitia__
# u: t_i_unitia__
# c: t_i_unitia__
# m: t_i_unitia__
# r: tri_unitiar_
# s: tri_unitiar_
# FAILURE
# GAME 11: kiefer
# e: __e_e_
# r: __e_er
# t: __e_er
# v: __e_er
# n: __e_er
# l: __e_er
# m: __e_er
# p: __e_er
# FAILURE
# GAME 12: biometrical
# e: ____e______
# i: _i__e__i___
# n: _i__e__i___
# t: _i__et_i___
# r: _i__etri___
# c: _i__etric__
# a: _i__etrica_
# l: _i__etrical
# m: _i_metrical
# o: _iometrical
# d: _iometrical
# h: _iometrical
# g: _iometrical
# b: biometrical
# SUCCESS
# GAME 13: earthquave
# e: e________e
# i: e________e
# a: ea_____a_e
# t: ea_t___a_e
# r: eart___a_e
# h: earth__a_e
# o: earth__a_e
# y: earth__a_e
# s: earth__a_e
# m: earth__a_e
# l: earth__a_e
# FAILURE
# GAME 14: kentrolite
# e: _e_______e
# i: _e_____i_e
# n: _en____i_e
# t: _ent___ite
# r: _entr__ite
# c: _entr__ite
# m: _entr__ite
# o: _entro_ite
# l: _entrolite
# p: _entrolite
# g: _entrolite
# s: _entrolite
# v: _entrolite
# FAILURE
# GAME 15: behavioristic
# e: _e___________
# i: _e___i__i__i_
# n: _e___i__i__i_
# t: _e___i__i_ti_
# s: _e___i__isti_
# c: _e___i__istic
# r: _e___i_ristic
# a: _e_a_i_ristic
# p: _e_a_i_ristic
# o: _e_a_ioristic
# l: _e_a_ioristic
# g: _e_a_ioristic
# m: _e_a_ioristic
# d: _e_a_ioristic
# FAILURE
# GAME 16: extortioners
# e: e________e__
# i: e_____i__e__
# r: e___r_i__er_
# t: e_t_rti__er_
# a: e_t_rti__er_
# o: e_tortio_er_
# n: e_tortioner_
# s: e_tortioners
# c: e_tortioners
# u: e_tortioners
# p: e_tortioners
# h: e_tortioners
# l: e_tortioners
# FAILURE
# GAME 17: macrochemical
# e: _______e_____
# i: _______e_i___
# r: ___r___e_i___
# n: ___r___e_i___
# l: ___r___e_i__l
# t: ___r___e_i__l
# m: m__r___emi__l
# s: m__r___emi__l
# a: ma_r___emi_al
# c: macr_c_emical
# h: macr_chemical
# o: macrochemical
# SUCCESS
# GAME 18: heinesque
# e: _e__e___e
# r: _e__e___e
# n: _e_ne___e
# d: _e_ne___e
# o: _e_ne___e
# a: _e_ne___e
# s: _e_nes__e
# t: _e_nes__e
# i: _eines__e
# h: heines__e
# c: heines__e
# FAILURE
# GAME 19: nonpastoral
# e: ___________
# i: ___________
# o: _o_____o___
# a: _o__a__o_a_
# n: non_a__o_a_
# c: non_a__o_a_
# s: non_as_o_a_
# t: non_asto_a_
# m: non_asto_a_
# r: non_astora_
# l: non_astoral
# f: non_astoral
# g: non_astoral
# FAILURE
# GAME 20: esthetical
# e: e___e_____
# i: e___e_i___
# r: e___e_i___
# m: e___e_i___
# n: e___e_i___
# l: e___e_i__l
# t: e_t_eti__l
# h: e_theti__l
# a: e_theti_al
# c: e_thetical
# o: e_thetical
# s: esthetical
# SUCCESS
# GAME 21: craspedote
# e: _____e___e
# i: _____e___e
# a: __a__e___e
# r: _ra__e___e
# t: _ra__e__te
# n: _ra__e__te
# s: _ras_e__te
# h: _ras_e__te
# c: cras_e__te
# p: craspe__te
# d: crasped_te
# o: craspedote
# SUCCESS
# GAME 22: chancily
# e: ________
# a: __a_____
# i: __a__i__
# n: __an_i__
# t: __an_i__
# d: __an_i__
# c: c_anci__
# r: c_anci__
# h: chanci__
# s: chanci__
# l: chancil_
# y: chancily
# SUCCESS
# GAME 23: microporosity
# e: _____________
# i: _i________i__
# o: _i__o_o_o_i__
# l: _i__o_o_o_i__
# n: _i__o_o_o_i__
# r: _i_ro_oro_i__
# t: _i_ro_oro_it_
# s: _i_ro_orosit_
# c: _icro_orosit_
# p: _icroporosit_
# m: microporosit_
# y: microporosity
# SUCCESS
# GAME 24: fordableness
# e: _______e_e__
# i: _______e_e__
# o: _o_____e_e__
# n: _o_____ene__
# s: _o_____eness
# l: _o____leness
# b: _o___bleness
# a: _o__ableness
# r: _or_ableness
# t: _or_ableness
# d: _ordableness
# f: fordableness
# SUCCESS
# GAME 25: starets
# e: ____e__
# a: __a_e__
# t: _ta_et_
# l: _ta_et_
# m: _ta_et_
# c: _ta_et_
# n: _ta_et_
# b: _ta_et_
# r: _taret_
# s: starets
# SUCCESS
# GAME 26: unbreeching
# e: ____ee_____
# i: ____ee__i__
# r: ___ree__i__
# t: ___ree__i__
# p: ___ree__i__
# n: _n_ree__in_
# g: _n_ree__ing
# c: _n_reec_ing
# h: _n_reeching
# f: _n_reeching
# d: _n_reeching
# a: _n_reeching
# b: _nbreeching
# u: unbreeching
# SUCCESS
# GAME 27: wardle
# e: _____e
# a: _a___e
# t: _a___e
# r: _ar__e
# i: _ar__e
# c: _ar__e
# n: _ar__e
# m: _ar__e
# l: _ar_le
# b: _ar_le
# FAILURE
# GAME 28: grandioso
# e: _________
# a: __a______
# i: __a__i___
# n: __an_i___
# t: __an_i___
# d: __andi___
# r: _randi___
# g: grandi___
# s: grandi_s_
# c: grandi_s_
# o: grandioso
# SUCCESS
# GAME 29: mannford
# e: ________
# a: _a______
# i: _a______
# o: _a___o__
# n: _ann_o__
# t: _ann_o__
# h: _ann_o__
# r: _ann_or_
# s: _ann_or_
# f: _annfor_
# m: mannfor_
# d: mannford
# SUCCESS
# GAME 30: dupleix
# e: ____e__
# a: ____e__
# i: ____ei_
# n: ____ei_
# r: ____ei_
# s: ____ei_
# t: ____ei_
# l: ___lei_
# c: ___lei_
# FAILURE
# GAME 31: soulfrighting
# e: _____________
# i: ______i___i__
# o: _o____i___i__
# n: _o____i___in_
# g: _o____ig__ing
# t: _o____ig_ting
# a: _o____ig_ting
# h: _o____ighting
# l: _o_l__ighting
# r: _o_l_righting
# b: _o_l_righting
# u: _oul_righting
# f: _oulfrighting
# s: soulfrighting
# SUCCESS
# GAME 32: leprously
# e: _e_______
# i: _e_______
# a: _e_______
# o: _e__o____
# r: _e_ro____
# t: _e_ro____
# p: _epro____
# c: _epro____
# s: _epro_s__
# u: _eprous__
# l: leprousl_
# y: leprously
# SUCCESS
# GAME 33: breezeshaken
# e: __ee_e____e_
# n: __ee_e____en
# r: _ree_e____en
# t: _ree_e____en
# d: _ree_e____en
# p: _ree_e____en
# c: _ree_e____en
# l: _ree_e____en
# g: _ree_e____en
# FAILURE
# GAME 34: selfsatisfaction
# e: _e______________
# i: _e_____i_____i__
# n: _e_____i_____i_n
# o: _e_____i_____ion
# t: _e____ti____tion
# a: _e___ati__a_tion
# c: _e___ati__action
# r: _e___ati__action
# f: _e_f_ati_faction
# s: se_fsatisfaction
# l: selfsatisfaction
# SUCCESS
# GAME 35: teind
# e: _e___
# a: _e___
# o: _e___
# i: _ei__
# n: _ein_
# g: _ein_
# r: _ein_
# s: _ein_
# t: tein_
# c: tein_
# FAILURE
# GAME 36: bleb
# a: ____
# e: __e_
# r: __e_
# n: __e_
# t: __e_
# l: _le_
# c: _le_
# p: _le_
# FAILURE
# GAME 37: lathesmen
# e: ____e__e_
# i: ____e__e_
# a: _a__e__e_
# r: _a__e__e_
# t: _at_e__e_
# h: _athe__e_
# m: _athe_me_
# n: _athe_men
# l: lathe_men
# d: lathe_men
# s: lathesmen
# SUCCESS
# GAME 38: acrostolium
# e: ___________
# i: ________i__
# a: a_______i__
# n: a_______i__
# t: a____t__i__
# r: a_r__t__i__
# c: acr__t__i__
# o: acro_to_i__
# s: acrosto_i__
# m: acrosto_i_m
# l: acrostoli_m
# u: acrostolium
# SUCCESS
# GAME 39: unshelve
# e: ____e__e
# r: ____e__e
# n: _n__e__e
# t: _n__e__e
# a: _n__e__e
# d: _n__e__e
# s: _ns_e__e
# h: _nshe__e
# u: unshe__e
# l: unshel_e
# m: unshel_e
# v: unshelve
# SUCCESS
# GAME 40: presanctifying
# e: __e___________
# i: __e_____i__i__
# n: __e__n__i__in_
# g: __e__n__i__ing
# t: __e__n_ti__ing
# s: __es_n_ti__ing
# o: __es_n_ti__ing
# a: __esan_ti__ing
# c: __esancti__ing
# r: _resancti__ing
# p: presancti__ing
# l: presancti__ing
# m: presancti__ing
# d: presancti__ing
# v: presancti__ing
# y: presancti_ying
# f: presanctifying
# SUCCESS
# GAME 41: pallescent
# e: ____e__e__
# i: ____e__e__
# a: _a__e__e__
# r: _a__e__e__
# t: _a__e__e_t
# n: _a__e__ent
# m: _a__e__ent
# l: _alle__ent
# c: _alle_cent
# s: _allescent
# b: _allescent
# g: _allescent
# p: pallescent
# SUCCESS
# GAME 42: selenigenous
# e: _e_e___e____
# r: _e_e___e____
# n: _e_en__en___
# t: _e_en__en___
# m: _e_en__en___
# v: _e_en__en___
# l: _elen__en___
# c: _elen__en___
# s: selen__en__s
# d: selen__en__s
# FAILURE
# GAME 43: hillman
# e: _______
# a: _____a_
# i: _i___a_
# n: _i___an
# r: _i___an
# l: _ill_an
# m: _illman
# v: _illman
# w: _illman
# h: hillman
# SUCCESS
# GAME 44: algedonic
# e: ___e_____
# i: ___e___i_
# r: ___e___i_
# n: ___e__ni_
# o: ___e_oni_
# c: ___e_onic
# m: ___e_onic
# t: ___e_onic
# g: __ge_onic
# s: __ge_onic
# l: _lge_onic
# d: _lgedonic
# a: algedonic
# SUCCESS
# GAME 45: schoening
# e: ____e____
# i: ____e_i__
# r: ____e_i__
# n: ____enin_
# g: ____ening
# t: ____ening
# m: ____ening
# v: ____ening
# l: ____ening
# h: __h_ening
# d: __h_ening
# FAILURE
# GAME 46: epappose
# e: e______e
# r: e______e
# t: e______e
# d: e______e
# n: e______e
# s: e_____se
# o: e____ose
# l: e____ose
# p: ep_ppose
# u: ep_ppose
# FAILURE
# GAME 47: recklinghausen
# e: _e__________e_
# i: _e___i______e_
# r: re___i______e_
# s: re___i_____se_
# d: re___i_____se_
# n: re___in____sen
# a: re___in__a_sen
# u: re___in__ausen
# l: re__lin__ausen
# g: re__ling_ausen
# h: re__linghausen
# o: re__linghausen
# t: re__linghausen
# p: re__linghausen
# y: re__linghausen
# c: rec_linghausen
# k: recklinghausen
# SUCCESS
# GAME 48: punchinelloes
# e: _______e___e_
# i: _____i_e___e_
# n: __n__ine___e_
# s: __n__ine___es
# t: __n__ine___es
# r: __n__ine___es
# l: __n__inell_es
# a: __n__inell_es
# o: __n__inelloes
# m: __n__inelloes
# g: __n__inelloes
# p: p_n__inelloes
# d: p_n__inelloes
# FAILURE
# GAME 49: phytosociologist
# e: ________________
# i: ________i____i__
# o: ____o_o_io_o_i__
# l: ____o_o_iolo_i__
# g: ____o_o_iologi__
# c: ____o_ociologi__
# s: ____osociologis_
# t: ___tosociologist
# a: ___tosociologist
# p: p__tosociologist
# n: p__tosociologist
# u: p__tosociologist
# r: p__tosociologist
# y: p_ytosociologist
# h: phytosociologist
# SUCCESS
# GAME 50: unfibered
# e: _____e_e_
# i: ___i_e_e_
# n: _n_i_e_e_
# t: _n_i_e_e_
# d: _n_i_e_ed
# r: _n_i_ered
# v: _n_i_ered
# p: _n_i_ered
# s: _n_i_ered
# b: _n_ibered
# l: _n_ibered
# a: _n_ibered
# FAILURE
# GAME 51: quasiinduced
# e: __________e_
# i: ____ii____e_
# r: ____ii____e_
# d: ____ii_d__ed
# n: ____iind__ed
# l: ____iind__ed
# a: __a_iind__ed
# t: __a_iind__ed
# s: __asiind__ed
# u: _uasiindu_ed
# c: _uasiinduced
# q: quasiinduced
# SUCCESS
# GAME 52: shargoss
# e: ________
# a: __a_____
# i: __a_____
# o: __a__o__
# n: __a__o__
# r: __ar_o__
# t: __ar_o__
# c: __ar_o__
# m: __ar_o__
# FAILURE
# GAME 53: hematorrhachis
# e: _e____________
# i: _e__________i_
# r: _e____rr____i_
# a: _e_a__rr_a__i_
# h: he_a__rrha_hi_
# p: he_a__rrha_hi_
# t: he_at_rrha_hi_
# o: he_atorrha_hi_
# m: hematorrha_hi_
# c: hematorrhachi_
# n: hematorrhachi_
# s: hematorrhachis
# SUCCESS
# GAME 54: truism
# e: ______
# a: ______
# o: ______
# i: ___i__
# u: __ui__
# t: t_ui__
# r: trui__
# s: truis_
# h: truis_
# m: truism
# SUCCESS
# GAME 55: counternarrative
# e: _____e_________e
# i: _____e_______i_e
# n: ___n_e_n_____i_e
# t: ___nte_n____ti_e
# r: ___ntern_rr_ti_e
# a: ___nternarrati_e
# o: _o_nternarrati_e
# u: _ounternarrati_e
# v: _ounternarrative
# c: counternarrative
# SUCCESS
# GAME 56: cytotoxic
# e: _________
# a: _________
# i: _______i_
# o: ___o_o_i_
# l: ___o_o_i_
# n: ___o_o_i_
# t: __toto_i_
# m: __toto_i_
# r: __toto_i_
# FAILURE
# GAME 57: sparkingly
# e: __________
# i: _____i____
# a: __a__i____
# n: __a__in___
# g: __a__ing__
# l: __a__ingl_
# y: __a__ingly
# t: __a__ingly
# r: __ar_ingly
# d: __ar_ingly
# k: __arkingly
# m: __arkingly
# w: __arkingly
# h: __arkingly
# FAILURE
# GAME 58: tydie
# e: ____e
# a: ____e
# o: ____e
# i: ___ie
# t: t__ie
# r: t__ie
# l: t__ie
# s: t__ie
# d: t_die
# u: t_die
# FAILURE
# GAME 59: swihart
# e: _______
# a: ____a__
# i: __i_a__
# c: __i_a__
# n: __i_a__
# t: __i_a_t
# s: s_i_a_t
# l: s_i_a_t
# r: s_i_art
# p: s_i_art
# m: s_i_art
# FAILURE
# GAME 60: noddling
# e: ________
# a: ________
# o: _o______
# i: _o___i__
# n: no___in_
# g: no___ing
# t: no___ing
# l: no__ling
# r: no__ling
# d: noddling
# SUCCESS
# GAME 61: suds
# a: ____
# e: ____
# o: ____
# i: ____
# u: _u__
# r: _u__
# t: _u__
# FAILURE
# GAME 62: sternbergia
# e: __e___e____
# i: __e___e__i_
# r: __er__er_i_
# t: _ter__er_i_
# s: ster__er_i_
# m: ster__er_i_
# a: ster__er_ia
# n: stern_er_ia
# d: stern_er_ia
# o: stern_er_ia
# g: stern_ergia
# b: sternbergia
# SUCCESS
# GAME 63: pelopea
# e: _e___e_
# r: _e___e_
# n: _e___e_
# t: _e___e_
# d: _e___e_
# l: _el__e_
# a: _el__ea
# i: _el__ea
# h: _el__ea
# FAILURE
# GAME 64: warblers
# e: _____e__
# a: _a___e__
# r: _ar__er_
# t: _ar__er_
# s: _ar__ers
# v: _ar__ers
# p: _ar__ers
# l: _ar_lers
# i: _ar_lers
# b: _arblers
# c: _arblers
# h: _arblers
# FAILURE
# GAME 65: undirectional
# e: _____e_______
# i: ___i_e__i____
# n: _n_i_e__i_n__
# o: _n_i_e__ion__
# t: _n_i_e_tion__
# a: _n_i_e_tiona_
# l: _n_i_e_tional
# c: _n_i_ectional
# f: _n_i_ectional
# r: _n_irectional
# d: _ndirectional
# u: undirectional
# SUCCESS
# GAME 66: wortham
# e: _______
# a: _____a_
# i: _____a_
# o: _o___a_
# n: _o___a_
# r: _or__a_
# t: _ort_a_
# h: _ortha_
# l: _ortha_
# p: _ortha_
# s: _ortha_
# FAILURE
# GAME 67: recurs
# e: _e____
# a: _e____
# i: _e____
# o: _e____
# u: _e_u__
# t: _e_u__
# r: re_ur_
# c: recur_
# s: recurs
# SUCCESS
# GAME 68: meddler
# e: _e___e_
# r: _e___er
# t: _e___er
# v: _e___er
# h: _e___er
# p: _e___er
# n: _e___er
# s: _e___er
# FAILURE
# GAME 69: mispraise
# e: ________e
# i: _i____i_e
# n: _i____i_e
# t: _i____i_e
# v: _i____i_e
# r: _i__r_i_e
# s: _is_r_ise
# a: _is_raise
# p: _ispraise
# d: _ispraise
# m: mispraise
# SUCCESS
# GAME 70: kilomoles
# e: _______e_
# i: _i_____e_
# n: _i_____e_
# r: _i_____e_
# t: _i_____e_
# s: _i_____es
# l: _il___les
# b: _il___les
# a: _il___les
# o: _ilo_oles
# p: _ilo_oles
# FAILURE
# GAME 71: tunneries
# e: ____e__e_
# i: ____e_ie_
# r: ____erie_
# s: ____eries
# t: t___eries
# p: t___eries
# v: t___eries
# h: t___eries
# n: t_nneries
# o: t_nneries
# a: t_nneries
# u: tunneries
# SUCCESS
# GAME 72: enteroscopy
# e: e__e_______
# i: e__e_______
# a: e__e_______
# o: e__e_o__o__
# r: e__ero__o__
# t: e_tero__o__
# n: entero__o__
# u: entero__o__
# s: enteros_o__
# c: enterosco__
# p: enteroscop_
# y: enteroscopy
# SUCCESS
# GAME 73: reality
# e: _e_____
# a: _ea____
# r: rea____
# d: rea____
# n: rea____
# t: rea__t_
# c: rea__t_
# l: real_t_
# i: realit_
# y: reality
# SUCCESS
# GAME 74: goniometrical
# e: ______e______
# i: ___i__e__i___
# n: __ni__e__i___
# a: __ni__e__i_a_
# c: __ni__e__ica_
# l: __ni__e__ical
# t: __ni__et_ical
# r: __ni__etrical
# m: __ni_metrical
# o: _oniometrical
# g: goniometrical
# SUCCESS
# GAME 75: dionize
# e: ______e
# a: ______e
# i: _i__i_e
# n: _i_ni_e
# o: _ioni_e
# t: _ioni_e
# z: _ionize
# s: _ionize
# r: _ionize
# g: _ionize
# l: _ionize
# FAILURE
# GAME 76: twelvelabor
# e: __e__e_____
# i: __e__e_____
# a: __e__e_a___
# r: __e__e_a__r
# t: t_e__e_a__r
# h: t_e__e_a__r
# l: t_el_ela__r
# v: t_elvela__r
# s: t_elvela__r
# w: twelvela__r
# n: twelvela__r
# b: twelvelab_r
# o: twelvelabor
# SUCCESS
# GAME 77: scrivaille
# e: _________e
# i: ___i__i__e
# n: ___i__i__e
# t: ___i__i__e
# s: s__i__i__e
# l: s__i__ille
# v: s__iv_ille
# o: s__iv_ille
# a: s__ivaille
# r: s_rivaille
# p: s_rivaille
# u: s_rivaille
# c: scrivaille
# SUCCESS
# GAME 78: heterochloridales
# e: _e_e___________e_
# i: _e_e_______i___e_
# r: _e_er_____ri___e_
# t: _eter_____ri___e_
# m: _eter_____ri___e_
# h: heter__h__ri___e_
# o: hetero_h_ori___e_
# p: hetero_h_ori___e_
# c: heteroch_ori___e_
# l: heterochlori__le_
# a: heterochlori_ale_
# n: heterochlori_ale_
# s: heterochlori_ales
# d: heterochloridales
# SUCCESS
# GAME 79: enterologic
# e: e__e_______
# i: e__e_____i_
# r: e__er____i_
# t: e_ter____i_
# n: enter____i_
# a: enter____i_
# s: enter____i_
# o: entero_o_i_
# l: enterolo_i_
# g: enterologi_
# c: enterologic
# SUCCESS
# GAME 80: biometrics
# e: ____e_____
# i: _i__e__i__
# n: _i__e__i__
# t: _i__et_i__
# r: _i__etri__
# c: _i__etric_
# a: _i__etric_
# m: _i_metric_
# o: _iometric_
# h: _iometric_
# k: _iometric_
# s: _iometrics
# d: _iometrics
# l: _iometrics
# FAILURE
# GAME 81: unelated
# e: __e___e_
# r: __e___e_
# n: _ne___e_
# s: _ne___e_
# t: _ne__te_
# a: _ne_ate_
# l: _nelate_
# d: _nelated
# o: _nelated
# u: unelated
# SUCCESS
# GAME 82: hypoglycemia
# e: ________e___
# i: ________e_i_
# r: ________e_i_
# n: ________e_i_
# l: _____l__e_i_
# t: _____l__e_i_
# m: _____l__emi_
# s: _____l__emi_
# a: _____l__emia
# h: h____l__emia
# d: h____l__emia
# c: h____l_cemia
# o: h__o_l_cemia
# y: hy_o_lycemia
# p: hypo_lycemia
# g: hypoglycemia
# SUCCESS
# GAME 83: trousseaux
# e: ______e___
# i: ______e___
# a: ______ea__
# r: _r____ea__
# t: tr____ea__
# o: tro___ea__
# p: tro___ea__
# c: tro___ea__
# n: tro___ea__
# s: tro_ssea__
# u: trousseau_
# l: trousseau_
# b: trousseau_
# FAILURE
# GAME 84: rascally
# e: ________
# a: _a__a___
# r: ra__a___
# n: ra__a___
# t: ra__a___
# c: ra_ca___
# s: rasca___
# l: rascall_
# y: rascally
# SUCCESS
# GAME 85: tooart
# e: ______
# a: ___a__
# i: ___a__
# o: _ooa__
# n: _ooa__
# r: _ooar_
# d: _ooar_
# c: _ooar_
# t: tooart
# SUCCESS
# GAME 86: palateless
# e: _____e_e__
# i: _____e_e__
# a: _a_a_e_e__
# t: _a_ate_e__
# r: _a_ate_e__
# l: _alatele__
# c: _alatele__
# s: _alateless
# p: palateless
# SUCCESS
# GAME 87: comices
# e: _____e_
# a: _____e_
# i: ___i_e_
# n: ___i_e_
# t: ___i_e_
# s: ___i_es
# r: ___i_es
# d: ___i_es
# l: ___i_es
# FAILURE
# GAME 88: thiever
# e: ___e_e_
# r: ___e_er
# t: t__e_er
# v: t__ever
# l: t__ever
# s: t__ever
# n: t__ever
# a: t__ever
# i: t_iever
# h: thiever
# SUCCESS
# GAME 89: arleen
# e: ___ee_
# r: _r_ee_
# s: _r_ee_
# n: _r_een
# t: _r_een
# h: _r_een
# d: _r_een
# i: _r_een
# w: _r_een
# FAILURE
# GAME 90: incircumspection
# e: __________e_____
# i: i__i______e__i__
# n: in_i______e__i_n
# t: in_i______e_ti_n
# o: in_i______e_tion
# a: in_i______e_tion
# c: inci_c____ection
# r: incirc____ection
# u: incircu___ection
# m: incircum__ection
# p: incircum_pection
# s: incircumspection
# SUCCESS
# GAME 91: reeper
# e: _ee_e_
# n: _ee_e_
# r: ree_er
# t: ree_er
# v: ree_er
# d: ree_er
# m: ree_er
# p: reeper
# SUCCESS
# GAME 92: bullions
# e: ________
# a: ________
# o: _____o__
# i: ____io__
# t: ____io__
# n: ____ion_
# s: ____ions
# r: ____ions
# d: ____ions
# l: __llions
# u: _ullions
# b: bullions
# SUCCESS
# GAME 93: wellheated
# e: _e___e__e_
# r: _e___e__e_
# n: _e___e__e_
# t: _e___e_te_
# s: _e___e_te_
# c: _e___e_te_
# l: _ell_e_te_
# a: _ell_eate_
# d: _ell_eated
# h: _ellheated
# w: wellheated
# SUCCESS
# GAME 94: vindicable
# e: _________e
# i: _i__i____e
# n: _in_i____e
# t: _in_i____e
# g: _in_i____e
# d: _indi____e
# l: _indi___le
# w: _indi___le
# r: _indi___le
# a: _indi_a_le
# b: _indi_able
# s: _indi_able
# c: _indicable
# m: _indicable
# FAILURE
# GAME 95: reasonal
# e: _e______
# a: _ea___a_
# r: rea___a_
# d: rea___a_
# n: rea__na_
# t: rea__na_
# l: rea__nal
# o: rea_onal
# g: rea_onal
# c: rea_onal
# s: reasonal
# SUCCESS
# GAME 96: panchromatic
# e: ____________
# i: __________i_
# a: _a______a_i_
# t: _a______ati_
# c: _a_c____atic
# m: _a_c___matic
# o: _a_c__omatic
# r: _a_c_romatic
# h: _a_chromatic
# n: _anchromatic
# l: _anchromatic
# s: _anchromatic
# d: _anchromatic
# p: panchromatic
# SUCCESS
# GAME 97: pogonophoran
# e: ____________
# i: ____________
# o: _o_o_o__o___
# l: _o_o_o__o___
# n: _o_ono__o__n
# m: _o_ono__o__n
# g: _ogono__o__n
# r: _ogono__or_n
# t: _ogono__or_n
# s: _ogono__or_n
# FAILURE
# GAME 98: worlddelighting
# e: ______e________
# i: ______e_i___i__
# r: __r___e_i___i__
# n: __r___e_i___in_
# g: __r___e_ig__ing
# l: __rl__elig__ing
# h: __rl__eligh_ing
# t: __rl__elighting
# d: __rlddelighting
# a: __rlddelighting
# o: _orlddelighting
# w: worlddelighting
# SUCCESS
# GAME 99: quakerly
# e: ____e___
# a: __a_e___
# t: __a_e___
# r: __a_er__
# v: __a_er__
# m: __a_er__
# n: __a_er__
# d: __a_er__
# p: __a_er__
# FAILURE
# GAME 100: wallington
# e: __________
# i: ____i_____
# a: _a__i_____
# t: _a__i__t__
# s: _a__i__t__
# n: _a__in_t_n
# g: _a__ingt_n
# o: _a__ington
# l: _allington
# c: _allington
# r: _allington
# b: _allington
# h: _allington
# FAILURE
# Success rate: 0.57
