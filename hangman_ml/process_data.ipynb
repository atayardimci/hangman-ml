# %%
import numpy as np
from sklearn.model_selection import train_test_split
from typing import Any

import h5py

import cProfile
import multiprocessing
from multiprocessing.managers import DictProxy

# %%
from utils.samples_and_labels import (
    build_len_to_most_frequent_letters,
    build_n_grams,
    save_data,
)

# %%
# Load the dictionary
dictionary_file_location = "./data/words_250000_train.txt"
text_file = open(dictionary_file_location,"r")
full_dictionary = text_file.read().splitlines()
text_file.close()

# %%
words_train, words_val = train_test_split(full_dictionary, test_size=0.2, random_state=42)
print(f"Number of words_train: {len(words_train)}")
print(f"Number of words_val: {len(words_val)}")
# Out:
# Number of words_train: 181840
# Number of words_val: 45460

# %%
# Obtain guess combinations with the most common letters in English
GUESSABLE_CHARS = {"e", "t", "a", "o", "i", "n"}
GUESSED_CHARS = set()

# Create a maximum of 50 samples per word
MAX_SAMPLES_PER_WORD = 50

LEN_TO_MOST_FREQUENT_LETTERS = build_len_to_most_frequent_letters(full_dictionary)
N_GRAMS = build_n_grams(full_dictionary)

# %%
def process_words(
    words_to_process: list[str],
    filename: str,
    start_from: int,
    end_at: int,
    batch_size: int,
    num_processes: int,
    cache: DictProxy,
    lock: Any,
):
    """Process words and save samples and labels in parallel."""
    assert num_processes < multiprocessing.cpu_count()

    chunk_size = (end_at - start_from) // num_processes + 1

    processes = []
    for i in range(num_processes):
        start = start_from + i * chunk_size
        end = min(start_from + (i + 1) * chunk_size, end_at)

        p = multiprocessing.Process(
            target=save_data,
            args=(
                words_to_process,
                GUESSED_CHARS,
                GUESSABLE_CHARS,
                MAX_SAMPLES_PER_WORD,
                filename,
                start,
                end,
                batch_size,
                cache,
                LEN_TO_MOST_FREQUENT_LETTERS,
                N_GRAMS,
                lock
            )
        )
        processes.append(p)
        p.start()

    for p in processes:
        p.join()

# %%
# Make sure to use same cache throughout preprocessing
manager = multiprocessing.Manager()
cache = manager.dict()

lock = multiprocessing.Lock()

# %%
FILENAME_TRAIN= "./data/train_data.h5"
FILENAME_VAL= "./data/validation_data.h5"

# %% [markdown]
# Training data
# ```
# 0       - 60,000 : done
# 60,000  - 120,000: done
# 120,000 - 181,840: done
# ```

# %% [markdown]
# Validation data
# ```
# 0       - 45,460 : done
# ```

# %% [markdown]
# Update `start_from` and `end_at` to process data

# %%
filename= FILENAME_TRAIN
words_to_process = words_train

start_from = 0
end_at = 181_840

batch_size = 250
num_processes = 9

process_words(
    words_to_process=words_to_process,
    filename=filename,
    start_from=start_from,
    end_at=end_at,
    batch_size=batch_size,
    num_processes=num_processes,
    cache=cache,
    lock=lock,
)
# Out:
# Processing: 100000-100250. End: 109094. Length of all words to process: 181840
# Processing: 109094-109344. End: 118188. Length of all words to process: 181840
# Processing: 100250-100500. End: 109094. Length of all words to process: 181840
# Processing: 118188-118438. End: 127282. Length of all words to process: 181840
# Processing: 109344-109594. End: 118188. Length of all words to process: 181840
# Processing: 127282-127532. End: 136376. Length of all words to process: 181840
# Processing: 100500-100750. End: 109094. Length of all words to process: 181840
# Processing: 136376-136626. End: 145470. Length of all words to process: 181840
# Processing: 118438-118688. End: 127282. Length of all words to process: 181840
# Processing: 145470-145720. End: 154564. Length of all words to process: 181840
# Processing: 109594-109844. End: 118188. Length of all words to process: 181840
# Processing: 127532-127782. End: 136376. Length of all words to process: 181840
# Processing: 154564-154814. End: 163658. Length of all words to process: 181840
# Processing: 136626-136876. End: 145470. Length of all words to process: 181840
# Processing: 118688-118938. End: 127282. Length of all words to process: 181840
# Processing: 100750-101000. End: 109094. Length of all words to process: 181840
# Processing: 163658-163908. End: 172752. Length of all words to process: 181840
# Processing: 172752-173002. End: 181840. Length of all words to process: 181840
# Processing: 145720-145970. End: 154564. Length of all words to process: 181840
# Processing: 109844-110094. End: 118188. Length of all words to process: 181840
# Processing: 127782-128032. End: 136376. Length of all words to process: 181840
# Processing: 154814-155064. End: 163658. Length of all words to process: 181840
# Processing: 136876-137126. End: 145470. Length of all words to process: 181840
# Processing: 118938-119188. End: 127282. Length of all words to process: 181840
# Processing: 101000-101250. End: 109094. Length of all words to process: 181840
# Processing: 163908-164158. End: 172752. Length of all words to process: 181840
# Processing: 173002-173252. End: 181840. Length of all words to process: 181840
# Processing: 110094-110344. End: 118188. Length of all words to process: 181840
# Processing: 145970-146220. End: 154564. Length of all words to process: 181840
# Processing: 128032-128282. End: 136376. Length of all words to process: 181840
# Processing: 155064-155314. End: 163658. Length of all words to process: 181840
# Processing: 137126-137376. End: 145470. Length of all words to process: 181840
# Processing: 101250-101500. End: 109094. Length of all words to process: 181840
# Processing: 119188-119438. End: 127282. Length of all words to process: 181840
# Processing: 164158-164408. End: 172752. Length of all words to process: 181840
# Processing: 173252-173502. End: 181840. Length of all words to process: 181840
# Processing: 110344-110594. End: 118188. Length of all words to process: 181840
# Processing: 146220-146470. End: 154564. Length of all words to process: 181840
# Processing: 128282-128532. End: 136376. Length of all words to process: 181840
# Processing: 155314-155564. End: 163658. Length of all words to process: 181840
# Processing: 137376-137626. End: 145470. Length of all words to process: 181840
# Processing: 119438-119688. End: 127282. Length of all words to process: 181840
# Processing: 101500-101750. End: 109094. Length of all words to process: 181840
# Processing: 164408-164658. End: 172752. Length of all words to process: 181840
# Processing: 173502-173752. End: 181840. Length of all words to process: 181840
# Processing: 110594-110844. End: 118188. Length of all words to process: 181840
# Processing: 146470-146720. End: 154564. Length of all words to process: 181840
# Processing: 128532-128782. End: 136376. Length of all words to process: 181840
# Processing: 155564-155814. End: 163658. Length of all words to process: 181840
# Processing: 137626-137876. End: 145470. Length of all words to process: 181840
# Processing: 101750-102000. End: 109094. Length of all words to process: 181840
# Processing: 119688-119938. End: 127282. Length of all words to process: 181840
# Processing: 164658-164908. End: 172752. Length of all words to process: 181840
# Processing: 173752-174002. End: 181840. Length of all words to process: 181840
# Processing: 110844-111094. End: 118188. Length of all words to process: 181840
# Processing: 146720-146970. End: 154564. Length of all words to process: 181840
# Processing: 128782-129032. End: 136376. Length of all words to process: 181840
# Processing: 155814-156064. End: 163658. Length of all words to process: 181840
# Processing: 137876-138126. End: 145470. Length of all words to process: 181840
# Processing: 102000-102250. End: 109094. Length of all words to process: 181840
# Processing: 119938-120188. End: 127282. Length of all words to process: 181840
# Processing: 164908-165158. End: 172752. Length of all words to process: 181840
# Processing: 174002-174252. End: 181840. Length of all words to process: 181840
# Processing: 111094-111344. End: 118188. Length of all words to process: 181840
# Processing: 146970-147220. End: 154564. Length of all words to process: 181840
# Processing: 129032-129282. End: 136376. Length of all words to process: 181840
# Processing: 156064-156314. End: 163658. Length of all words to process: 181840
# Processing: 138126-138376. End: 145470. Length of all words to process: 181840
# Processing: 102250-102500. End: 109094. Length of all words to process: 181840
# Processing: 120188-120438. End: 127282. Length of all words to process: 181840
# Processing: 165158-165408. End: 172752. Length of all words to process: 181840
# Processing: 174252-174502. End: 181840. Length of all words to process: 181840
# Processing: 111344-111594. End: 118188. Length of all words to process: 181840
# Processing: 147220-147470. End: 154564. Length of all words to process: 181840
# Processing: 129282-129532. End: 136376. Length of all words to process: 181840
# Processing: 156314-156564. End: 163658. Length of all words to process: 181840
# Processing: 138376-138626. End: 145470. Length of all words to process: 181840
# Processing: 102500-102750. End: 109094. Length of all words to process: 181840
# Processing: 120438-120688. End: 127282. Length of all words to process: 181840
# Processing: 165408-165658. End: 172752. Length of all words to process: 181840
# Processing: 174502-174752. End: 181840. Length of all words to process: 181840
# Processing: 111594-111844. End: 118188. Length of all words to process: 181840
# Processing: 147470-147720. End: 154564. Length of all words to process: 181840
# Processing: 129532-129782. End: 136376. Length of all words to process: 181840
# Processing: 156564-156814. End: 163658. Length of all words to process: 181840
# Processing: 138626-138876. End: 145470. Length of all words to process: 181840
# Processing: 102750-103000. End: 109094. Length of all words to process: 181840
# Processing: 120688-120938. End: 127282. Length of all words to process: 181840
# Processing: 165658-165908. End: 172752. Length of all words to process: 181840
# Processing: 174752-175002. End: 181840. Length of all words to process: 181840
# Processing: 147720-147970. End: 154564. Length of all words to process: 181840
# Processing: 111844-112094. End: 118188. Length of all words to process: 181840
# Processing: 129782-130032. End: 136376. Length of all words to process: 181840
# Processing: 156814-157064. End: 163658. Length of all words to process: 181840
# Processing: 138876-139126. End: 145470. Length of all words to process: 181840
# Processing: 103000-103250. End: 109094. Length of all words to process: 181840
# Processing: 120938-121188. End: 127282. Length of all words to process: 181840
# Processing: 165908-166158. End: 172752. Length of all words to process: 181840
# Processing: 147970-148220. End: 154564. Length of all words to process: 181840
# Processing: 175002-175252. End: 181840. Length of all words to process: 181840
# Processing: 112094-112344. End: 118188. Length of all words to process: 181840
# Processing: 130032-130282. End: 136376. Length of all words to process: 181840
# Processing: 157064-157314. End: 163658. Length of all words to process: 181840
# Processing: 139126-139376. End: 145470. Length of all words to process: 181840
# Processing: 103250-103500. End: 109094. Length of all words to process: 181840
# Processing: 121188-121438. End: 127282. Length of all words to process: 181840
# Processing: 166158-166408. End: 172752. Length of all words to process: 181840
# Processing: 148220-148470. End: 154564. Length of all words to process: 181840
# Processing: 175252-175502. End: 181840. Length of all words to process: 181840
# Processing: 112344-112594. End: 118188. Length of all words to process: 181840
# Processing: 130282-130532. End: 136376. Length of all words to process: 181840
# Processing: 157314-157564. End: 163658. Length of all words to process: 181840
# Processing: 139376-139626. End: 145470. Length of all words to process: 181840
# Processing: 103500-103750. End: 109094. Length of all words to process: 181840
# Processing: 121438-121688. End: 127282. Length of all words to process: 181840
# Processing: 166408-166658. End: 172752. Length of all words to process: 181840
# Processing: 148470-148720. End: 154564. Length of all words to process: 181840
# Processing: 175502-175752. End: 181840. Length of all words to process: 181840
# Processing: 112594-112844. End: 118188. Length of all words to process: 181840
# Processing: 130532-130782. End: 136376. Length of all words to process: 181840
# Processing: 157564-157814. End: 163658. Length of all words to process: 181840
# Processing: 139626-139876. End: 145470. Length of all words to process: 181840
# Processing: 103750-104000. End: 109094. Length of all words to process: 181840
# Processing: 121688-121938. End: 127282. Length of all words to process: 181840
# Processing: 166658-166908. End: 172752. Length of all words to process: 181840
# Processing: 148720-148970. End: 154564. Length of all words to process: 181840
# Processing: 175752-176002. End: 181840. Length of all words to process: 181840
# Processing: 112844-113094. End: 118188. Length of all words to process: 181840
# Processing: 130782-131032. End: 136376. Length of all words to process: 181840
# Processing: 157814-158064. End: 163658. Length of all words to process: 181840
# Processing: 139876-140126. End: 145470. Length of all words to process: 181840
# Processing: 104000-104250. End: 109094. Length of all words to process: 181840
# Processing: 121938-122188. End: 127282. Length of all words to process: 181840
# Processing: 166908-167158. End: 172752. Length of all words to process: 181840
# Processing: 113094-113344. End: 118188. Length of all words to process: 181840
# Processing: 176002-176252. End: 181840. Length of all words to process: 181840
# Processing: 148970-149220. End: 154564. Length of all words to process: 181840
# Processing: 131032-131282. End: 136376. Length of all words to process: 181840
# Processing: 158064-158314. End: 163658. Length of all words to process: 181840
# Processing: 140126-140376. End: 145470. Length of all words to process: 181840
# Processing: 104250-104500. End: 109094. Length of all words to process: 181840
# Processing: 122188-122438. End: 127282. Length of all words to process: 181840
# Processing: 167158-167408. End: 172752. Length of all words to process: 181840
# Processing: 176252-176502. End: 181840. Length of all words to process: 181840
# Processing: 113344-113594. End: 118188. Length of all words to process: 181840
# Processing: 149220-149470. End: 154564. Length of all words to process: 181840
# Processing: 131282-131532. End: 136376. Length of all words to process: 181840
# Processing: 158314-158564. End: 163658. Length of all words to process: 181840
# Processing: 140376-140626. End: 145470. Length of all words to process: 181840
# Processing: 104500-104750. End: 109094. Length of all words to process: 181840
# Processing: 122438-122688. End: 127282. Length of all words to process: 181840
# Processing: 167408-167658. End: 172752. Length of all words to process: 181840
# Processing: 113594-113844. End: 118188. Length of all words to process: 181840
# Processing: 176502-176752. End: 181840. Length of all words to process: 181840
# Processing: 149470-149720. End: 154564. Length of all words to process: 181840
# Processing: 131532-131782. End: 136376. Length of all words to process: 181840
# Processing: 158564-158814. End: 163658. Length of all words to process: 181840
# Processing: 140626-140876. End: 145470. Length of all words to process: 181840
# Processing: 104750-105000. End: 109094. Length of all words to process: 181840
# Processing: 122688-122938. End: 127282. Length of all words to process: 181840
# Processing: 167658-167908. End: 172752. Length of all words to process: 181840
# Processing: 176752-177002. End: 181840. Length of all words to process: 181840
# Processing: 113844-114094. End: 118188. Length of all words to process: 181840
# Processing: 149720-149970. End: 154564. Length of all words to process: 181840
# Processing: 131782-132032. End: 136376. Length of all words to process: 181840
# Processing: 158814-159064. End: 163658. Length of all words to process: 181840
# Processing: 140876-141126. End: 145470. Length of all words to process: 181840
# Processing: 105000-105250. End: 109094. Length of all words to process: 181840
# Processing: 122938-123188. End: 127282. Length of all words to process: 181840
# Processing: 167908-168158. End: 172752. Length of all words to process: 181840
# Processing: 114094-114344. End: 118188. Length of all words to process: 181840
# Processing: 177002-177252. End: 181840. Length of all words to process: 181840
# Processing: 149970-150220. End: 154564. Length of all words to process: 181840
# Processing: 132032-132282. End: 136376. Length of all words to process: 181840
# Processing: 159064-159314. End: 163658. Length of all words to process: 181840
# Processing: 141126-141376. End: 145470. Length of all words to process: 181840
# Processing: 105250-105500. End: 109094. Length of all words to process: 181840
# Processing: 168158-168408. End: 172752. Length of all words to process: 181840
# Processing: 123188-123438. End: 127282. Length of all words to process: 181840
# Processing: 114344-114594. End: 118188. Length of all words to process: 181840
# Processing: 177252-177502. End: 181840. Length of all words to process: 181840
# Processing: 150220-150470. End: 154564. Length of all words to process: 181840
# Processing: 132282-132532. End: 136376. Length of all words to process: 181840
# Processing: 159314-159564. End: 163658. Length of all words to process: 181840
# Processing: 141376-141626. End: 145470. Length of all words to process: 181840
# Processing: 105500-105750. End: 109094. Length of all words to process: 181840
# Processing: 168408-168658. End: 172752. Length of all words to process: 181840
# Processing: 123438-123688. End: 127282. Length of all words to process: 181840
# Processing: 114594-114844. End: 118188. Length of all words to process: 181840
# Processing: 177502-177752. End: 181840. Length of all words to process: 181840
# Processing: 150470-150720. End: 154564. Length of all words to process: 181840
# Processing: 132532-132782. End: 136376. Length of all words to process: 181840
# Processing: 159564-159814. End: 163658. Length of all words to process: 181840
# Processing: 141626-141876. End: 145470. Length of all words to process: 181840
# Processing: 168658-168908. End: 172752. Length of all words to process: 181840
# Processing: 105750-106000. End: 109094. Length of all words to process: 181840
# Processing: 123688-123938. End: 127282. Length of all words to process: 181840
# Processing: 114844-115094. End: 118188. Length of all words to process: 181840
# Processing: 177752-178002. End: 181840. Length of all words to process: 181840
# Processing: 150720-150970. End: 154564. Length of all words to process: 181840
# Processing: 132782-133032. End: 136376. Length of all words to process: 181840
# Processing: 159814-160064. End: 163658. Length of all words to process: 181840
# Processing: 141876-142126. End: 145470. Length of all words to process: 181840
# Processing: 168908-169158. End: 172752. Length of all words to process: 181840
# Processing: 106000-106250. End: 109094. Length of all words to process: 181840
# Processing: 123938-124188. End: 127282. Length of all words to process: 181840
# Processing: 115094-115344. End: 118188. Length of all words to process: 181840
# Processing: 178002-178252. End: 181840. Length of all words to process: 181840
# Processing: 150970-151220. End: 154564. Length of all words to process: 181840
# Processing: 133032-133282. End: 136376. Length of all words to process: 181840
# Processing: 160064-160314. End: 163658. Length of all words to process: 181840
# Processing: 142126-142376. End: 145470. Length of all words to process: 181840
# Processing: 169158-169408. End: 172752. Length of all words to process: 181840
# Processing: 106250-106500. End: 109094. Length of all words to process: 181840
# Processing: 124188-124438. End: 127282. Length of all words to process: 181840
# Processing: 115344-115594. End: 118188. Length of all words to process: 181840
# Processing: 178252-178502. End: 181840. Length of all words to process: 181840
# Processing: 151220-151470. End: 154564. Length of all words to process: 181840
# Processing: 133282-133532. End: 136376. Length of all words to process: 181840
# Processing: 160314-160564. End: 163658. Length of all words to process: 181840
# Processing: 142376-142626. End: 145470. Length of all words to process: 181840
# Processing: 106500-106750. End: 109094. Length of all words to process: 181840
# Processing: 169408-169658. End: 172752. Length of all words to process: 181840
# Processing: 124438-124688. End: 127282. Length of all words to process: 181840
# Processing: 115594-115844. End: 118188. Length of all words to process: 181840
# Processing: 178502-178752. End: 181840. Length of all words to process: 181840
# Processing: 151470-151720. End: 154564. Length of all words to process: 181840
# Processing: 133532-133782. End: 136376. Length of all words to process: 181840
# Processing: 160564-160814. End: 163658. Length of all words to process: 181840
# Processing: 142626-142876. End: 145470. Length of all words to process: 181840
# Processing: 106750-107000. End: 109094. Length of all words to process: 181840
# Processing: 169658-169908. End: 172752. Length of all words to process: 181840
# Processing: 124688-124938. End: 127282. Length of all words to process: 181840
# Processing: 115844-116094. End: 118188. Length of all words to process: 181840
# Processing: 178752-179002. End: 181840. Length of all words to process: 181840
# Processing: 151720-151970. End: 154564. Length of all words to process: 181840
# Processing: 133782-134032. End: 136376. Length of all words to process: 181840
# Processing: 160814-161064. End: 163658. Length of all words to process: 181840
# Processing: 142876-143126. End: 145470. Length of all words to process: 181840
# Processing: 169908-170158. End: 172752. Length of all words to process: 181840
# Processing: 107000-107250. End: 109094. Length of all words to process: 181840
# Processing: 124938-125188. End: 127282. Length of all words to process: 181840
# Processing: 116094-116344. End: 118188. Length of all words to process: 181840
# Processing: 179002-179252. End: 181840. Length of all words to process: 181840
# Processing: 151970-152220. End: 154564. Length of all words to process: 181840
# Processing: 134032-134282. End: 136376. Length of all words to process: 181840
# Processing: 161064-161314. End: 163658. Length of all words to process: 181840
# Processing: 143126-143376. End: 145470. Length of all words to process: 181840
# Processing: 107250-107500. End: 109094. Length of all words to process: 181840
# Processing: 170158-170408. End: 172752. Length of all words to process: 181840
# Processing: 125188-125438. End: 127282. Length of all words to process: 181840
# Processing: 116344-116594. End: 118188. Length of all words to process: 181840
# Processing: 152220-152470. End: 154564. Length of all words to process: 181840
# Processing: 179252-179502. End: 181840. Length of all words to process: 181840
# Processing: 134282-134532. End: 136376. Length of all words to process: 181840
# Processing: 161314-161564. End: 163658. Length of all words to process: 181840
# Processing: 143376-143626. End: 145470. Length of all words to process: 181840
# Processing: 170408-170658. End: 172752. Length of all words to process: 181840
# Processing: 107500-107750. End: 109094. Length of all words to process: 181840
# Processing: 125438-125688. End: 127282. Length of all words to process: 181840
# Processing: 116594-116844. End: 118188. Length of all words to process: 181840
# Processing: 179502-179752. End: 181840. Length of all words to process: 181840
# Processing: 152470-152720. End: 154564. Length of all words to process: 181840
# Processing: 134532-134782. End: 136376. Length of all words to process: 181840
# Processing: 161564-161814. End: 163658. Length of all words to process: 181840
# Processing: 143626-143876. End: 145470. Length of all words to process: 181840
# Processing: 170658-170908. End: 172752. Length of all words to process: 181840
# Processing: 107750-108000. End: 109094. Length of all words to process: 181840
# Processing: 125688-125938. End: 127282. Length of all words to process: 181840
# Processing: 116844-117094. End: 118188. Length of all words to process: 181840
# Processing: 134782-135032. End: 136376. Length of all words to process: 181840
# Processing: 179752-180002. End: 181840. Length of all words to process: 181840
# Processing: 152720-152970. End: 154564. Length of all words to process: 181840
# Processing: 161814-162064. End: 163658. Length of all words to process: 181840
# Processing: 143876-144126. End: 145470. Length of all words to process: 181840
# Processing: 170908-171158. End: 172752. Length of all words to process: 181840
# Processing: 108000-108250. End: 109094. Length of all words to process: 181840
# Processing: 125938-126188. End: 127282. Length of all words to process: 181840
# Processing: 117094-117344. End: 118188. Length of all words to process: 181840
# Processing: 135032-135282. End: 136376. Length of all words to process: 181840
# Processing: 152970-153220. End: 154564. Length of all words to process: 181840
# Processing: 180002-180252. End: 181840. Length of all words to process: 181840
# Processing: 162064-162314. End: 163658. Length of all words to process: 181840
# Processing: 144126-144376. End: 145470. Length of all words to process: 181840
# Processing: 171158-171408. End: 172752. Length of all words to process: 181840
# Processing: 108250-108500. End: 109094. Length of all words to process: 181840
# Processing: 126188-126438. End: 127282. Length of all words to process: 181840
# Processing: 117344-117594. End: 118188. Length of all words to process: 181840
# Processing: 153220-153470. End: 154564. Length of all words to process: 181840
# Processing: 135282-135532. End: 136376. Length of all words to process: 181840
# Processing: 180252-180502. End: 181840. Length of all words to process: 181840
# Processing: 162314-162564. End: 163658. Length of all words to process: 181840
# Processing: 144376-144626. End: 145470. Length of all words to process: 181840
# Processing: 108500-108750. End: 109094. Length of all words to process: 181840
# Processing: 171408-171658. End: 172752. Length of all words to process: 181840
# Processing: 126438-126688. End: 127282. Length of all words to process: 181840
# Processing: 117594-117844. End: 118188. Length of all words to process: 181840
# Processing: 153470-153720. End: 154564. Length of all words to process: 181840
# Processing: 135532-135782. End: 136376. Length of all words to process: 181840
# Processing: 180502-180752. End: 181840. Length of all words to process: 181840
# Processing: 162564-162814. End: 163658. Length of all words to process: 181840
# Processing: 144626-144876. End: 145470. Length of all words to process: 181840
# Processing: 108750-109000. End: 109094. Length of all words to process: 181840
# Processing: 171658-171908. End: 172752. Length of all words to process: 181840
# Processing: 126688-126938. End: 127282. Length of all words to process: 181840
# Processing: 117844-118094. End: 118188. Length of all words to process: 181840
# Processing: 153720-153970. End: 154564. Length of all words to process: 181840
# Processing: 135782-136032. End: 136376. Length of all words to process: 181840
# Processing: 180752-181002. End: 181840. Length of all words to process: 181840
# Processing: 162814-163064. End: 163658. Length of all words to process: 181840
# Processing: 144876-145126. End: 145470. Length of all words to process: 181840
# Processing: 109000-109094. End: 109094. Length of all words to process: 181840
# Processing: 171908-172158. End: 172752. Length of all words to process: 181840
# Processing: 126938-127188. End: 127282. Length of all words to process: 181840
# Finished processing: 100000-109094
# Processing: 118094-118188. End: 118188. Length of all words to process: 181840
# Processing: 153970-154220. End: 154564. Length of all words to process: 181840
# Processing: 136032-136282. End: 136376. Length of all words to process: 181840
# Processing: 181002-181252. End: 181840. Length of all words to process: 181840
# Finished processing: 109094-118188
# Processing: 163064-163314. End: 163658. Length of all words to process: 181840
# Processing: 145126-145376. End: 145470. Length of all words to process: 181840
# Processing: 172158-172408. End: 172752. Length of all words to process: 181840
# Processing: 127188-127282. End: 127282. Length of all words to process: 181840
# Processing: 154220-154470. End: 154564. Length of all words to process: 181840
# Processing: 136282-136376. End: 136376. Length of all words to process: 181840
# Finished processing: 118188-127282
# Processing: 181252-181502. End: 181840. Length of all words to process: 181840
# Processing: 163314-163564. End: 163658. Length of all words to process: 181840
# Finished processing: 127282-136376
# Processing: 145376-145470. End: 145470. Length of all words to process: 181840
# Processing: 172408-172658. End: 172752. Length of all words to process: 181840
# Finished processing: 136376-145470
# Processing: 154470-154564. End: 154564. Length of all words to process: 181840
# Processing: 181502-181752. End: 181840. Length of all words to process: 181840
# Processing: 163564-163658. End: 163658. Length of all words to process: 181840
# Finished processing: 145470-154564
# Processing: 172658-172752. End: 172752. Length of all words to process: 181840
# Finished processing: 154564-163658
# Finished processing: 163658-172752
# Processing: 181752-181840. End: 181840. Length of all words to process: 181840
# Finished processing: 172752-181840

# %%
filename= FILENAME_VAL
words_to_process = words_val

start_from = 0
end_at = 45_460

batch_size = 250
num_processes = 9

process_words(
    words_to_process=words_to_process,
    filename=filename,
    start_from=start_from,
    end_at=end_at,
    batch_size=batch_size,
    num_processes=num_processes,
    cache=cache,
    lock=lock,
)
# Out:
# Processing: 0-250. End: 5052. Length of all words to process: 45460
# Processing: 5052-5302. End: 10104. Length of all words to process: 45460
# Processing: 250-500. End: 5052. Length of all words to process: 45460
# Processing: 10104-10354. End: 15156. Length of all words to process: 45460
# Processing: 5302-5552. End: 10104. Length of all words to process: 45460
# Processing: 15156-15406. End: 20208. Length of all words to process: 45460
# Processing: 500-750. End: 5052. Length of all words to process: 45460
# Processing: 20208-20458. End: 25260. Length of all words to process: 45460
# Processing: 10354-10604. End: 15156. Length of all words to process: 45460
# Processing: 25260-25510. End: 30312. Length of all words to process: 45460
# Processing: 5552-5802. End: 10104. Length of all words to process: 45460
# Processing: 15406-15656. End: 20208. Length of all words to process: 45460
# Processing: 30312-30562. End: 35364. Length of all words to process: 45460
# Processing: 750-1000. End: 5052. Length of all words to process: 45460
# Processing: 20458-20708. End: 25260. Length of all words to process: 45460
# Processing: 35364-35614. End: 40416. Length of all words to process: 45460
# Processing: 10604-10854. End: 15156. Length of all words to process: 45460
# Processing: 40416-40666. End: 45460. Length of all words to process: 45460
# Processing: 25510-25760. End: 30312. Length of all words to process: 45460
# Processing: 5802-6052. End: 10104. Length of all words to process: 45460
# Processing: 15656-15906. End: 20208. Length of all words to process: 45460
# Processing: 30562-30812. End: 35364. Length of all words to process: 45460
# Processing: 1000-1250. End: 5052. Length of all words to process: 45460
# Processing: 20708-20958. End: 25260. Length of all words to process: 45460
# Processing: 10854-11104. End: 15156. Length of all words to process: 45460
# Processing: 35614-35864. End: 40416. Length of all words to process: 45460
# Processing: 40666-40916. End: 45460. Length of all words to process: 45460
# Processing: 25760-26010. End: 30312. Length of all words to process: 45460
# Processing: 6052-6302. End: 10104. Length of all words to process: 45460
# Processing: 15906-16156. End: 20208. Length of all words to process: 45460
# Processing: 30812-31062. End: 35364. Length of all words to process: 45460
# Processing: 1250-1500. End: 5052. Length of all words to process: 45460
# Processing: 20958-21208. End: 25260. Length of all words to process: 45460
# Processing: 35864-36114. End: 40416. Length of all words to process: 45460
# Processing: 11104-11354. End: 15156. Length of all words to process: 45460
# Processing: 40916-41166. End: 45460. Length of all words to process: 45460
# Processing: 6302-6552. End: 10104. Length of all words to process: 45460
# Processing: 26010-26260. End: 30312. Length of all words to process: 45460
# Processing: 16156-16406. End: 20208. Length of all words to process: 45460
# Processing: 31062-31312. End: 35364. Length of all words to process: 45460
# Processing: 1500-1750. End: 5052. Length of all words to process: 45460
# Processing: 21208-21458. End: 25260. Length of all words to process: 45460
# Processing: 36114-36364. End: 40416. Length of all words to process: 45460
# Processing: 11354-11604. End: 15156. Length of all words to process: 45460
# Processing: 41166-41416. End: 45460. Length of all words to process: 45460
# Processing: 6552-6802. End: 10104. Length of all words to process: 45460
# Processing: 26260-26510. End: 30312. Length of all words to process: 45460
# Processing: 16406-16656. End: 20208. Length of all words to process: 45460
# Processing: 31312-31562. End: 35364. Length of all words to process: 45460
# Processing: 1750-2000. End: 5052. Length of all words to process: 45460
# Processing: 21458-21708. End: 25260. Length of all words to process: 45460
# Processing: 36364-36614. End: 40416. Length of all words to process: 45460
# Processing: 11604-11854. End: 15156. Length of all words to process: 45460
# Processing: 41416-41666. End: 45460. Length of all words to process: 45460
# Processing: 6802-7052. End: 10104. Length of all words to process: 45460
# Processing: 26510-26760. End: 30312. Length of all words to process: 45460
# Processing: 16656-16906. End: 20208. Length of all words to process: 45460
# Processing: 31562-31812. End: 35364. Length of all words to process: 45460
# Processing: 2000-2250. End: 5052. Length of all words to process: 45460
# Processing: 21708-21958. End: 25260. Length of all words to process: 45460
# Processing: 36614-36864. End: 40416. Length of all words to process: 45460
# Processing: 11854-12104. End: 15156. Length of all words to process: 45460
# Processing: 41666-41916. End: 45460. Length of all words to process: 45460
# Processing: 7052-7302. End: 10104. Length of all words to process: 45460
# Processing: 26760-27010. End: 30312. Length of all words to process: 45460
# Processing: 16906-17156. End: 20208. Length of all words to process: 45460
# Processing: 31812-32062. End: 35364. Length of all words to process: 45460
# Processing: 2250-2500. End: 5052. Length of all words to process: 45460
# Processing: 21958-22208. End: 25260. Length of all words to process: 45460
# Processing: 12104-12354. End: 15156. Length of all words to process: 45460
# Processing: 36864-37114. End: 40416. Length of all words to process: 45460
# Processing: 41916-42166. End: 45460. Length of all words to process: 45460
# Processing: 7302-7552. End: 10104. Length of all words to process: 45460
# Processing: 27010-27260. End: 30312. Length of all words to process: 45460
# Processing: 17156-17406. End: 20208. Length of all words to process: 45460
# Processing: 32062-32312. End: 35364. Length of all words to process: 45460
# Processing: 2500-2750. End: 5052. Length of all words to process: 45460
# Processing: 22208-22458. End: 25260. Length of all words to process: 45460
# Processing: 37114-37364. End: 40416. Length of all words to process: 45460
# Processing: 12354-12604. End: 15156. Length of all words to process: 45460
# Processing: 42166-42416. End: 45460. Length of all words to process: 45460
# Processing: 7552-7802. End: 10104. Length of all words to process: 45460
# Processing: 27260-27510. End: 30312. Length of all words to process: 45460
# Processing: 17406-17656. End: 20208. Length of all words to process: 45460
# Processing: 32312-32562. End: 35364. Length of all words to process: 45460
# Processing: 2750-3000. End: 5052. Length of all words to process: 45460
# Processing: 22458-22708. End: 25260. Length of all words to process: 45460
# Processing: 37364-37614. End: 40416. Length of all words to process: 45460
# Processing: 12604-12854. End: 15156. Length of all words to process: 45460
# Processing: 42416-42666. End: 45460. Length of all words to process: 45460
# Processing: 7802-8052. End: 10104. Length of all words to process: 45460
# Processing: 27510-27760. End: 30312. Length of all words to process: 45460
# Processing: 17656-17906. End: 20208. Length of all words to process: 45460
# Processing: 32562-32812. End: 35364. Length of all words to process: 45460
# Processing: 3000-3250. End: 5052. Length of all words to process: 45460
# Processing: 22708-22958. End: 25260. Length of all words to process: 45460
# Processing: 37614-37864. End: 40416. Length of all words to process: 45460
# Processing: 12854-13104. End: 15156. Length of all words to process: 45460
# Processing: 42666-42916. End: 45460. Length of all words to process: 45460
# Processing: 8052-8302. End: 10104. Length of all words to process: 45460
# Processing: 27760-28010. End: 30312. Length of all words to process: 45460
# Processing: 17906-18156. End: 20208. Length of all words to process: 45460
# Processing: 32812-33062. End: 35364. Length of all words to process: 45460
# Processing: 3250-3500. End: 5052. Length of all words to process: 45460
# Processing: 22958-23208. End: 25260. Length of all words to process: 45460
# Processing: 13104-13354. End: 15156. Length of all words to process: 45460
# Processing: 37864-38114. End: 40416. Length of all words to process: 45460
# Processing: 42916-43166. End: 45460. Length of all words to process: 45460
# Processing: 8302-8552. End: 10104. Length of all words to process: 45460
# Processing: 28010-28260. End: 30312. Length of all words to process: 45460
# Processing: 18156-18406. End: 20208. Length of all words to process: 45460
# Processing: 33062-33312. End: 35364. Length of all words to process: 45460
# Processing: 3500-3750. End: 5052. Length of all words to process: 45460
# Processing: 23208-23458. End: 25260. Length of all words to process: 45460
# Processing: 13354-13604. End: 15156. Length of all words to process: 45460
# Processing: 38114-38364. End: 40416. Length of all words to process: 45460
# Processing: 43166-43416. End: 45460. Length of all words to process: 45460
# Processing: 8552-8802. End: 10104. Length of all words to process: 45460
# Processing: 28260-28510. End: 30312. Length of all words to process: 45460
# Processing: 18406-18656. End: 20208. Length of all words to process: 45460
# Processing: 33312-33562. End: 35364. Length of all words to process: 45460
# Processing: 3750-4000. End: 5052. Length of all words to process: 45460
# Processing: 23458-23708. End: 25260. Length of all words to process: 45460
# Processing: 13604-13854. End: 15156. Length of all words to process: 45460
# Processing: 38364-38614. End: 40416. Length of all words to process: 45460
# Processing: 43416-43666. End: 45460. Length of all words to process: 45460
# Processing: 8802-9052. End: 10104. Length of all words to process: 45460
# Processing: 28510-28760. End: 30312. Length of all words to process: 45460
# Processing: 18656-18906. End: 20208. Length of all words to process: 45460
# Processing: 33562-33812. End: 35364. Length of all words to process: 45460
# Processing: 4000-4250. End: 5052. Length of all words to process: 45460
# Processing: 23708-23958. End: 25260. Length of all words to process: 45460
# Processing: 13854-14104. End: 15156. Length of all words to process: 45460
# Processing: 38614-38864. End: 40416. Length of all words to process: 45460
# Processing: 43666-43916. End: 45460. Length of all words to process: 45460
# Processing: 9052-9302. End: 10104. Length of all words to process: 45460
# Processing: 28760-29010. End: 30312. Length of all words to process: 45460
# Processing: 18906-19156. End: 20208. Length of all words to process: 45460
# Processing: 33812-34062. End: 35364. Length of all words to process: 45460
# Processing: 4250-4500. End: 5052. Length of all words to process: 45460
# Processing: 23958-24208. End: 25260. Length of all words to process: 45460
# Processing: 14104-14354. End: 15156. Length of all words to process: 45460
# Processing: 38864-39114. End: 40416. Length of all words to process: 45460
# Processing: 43916-44166. End: 45460. Length of all words to process: 45460
# Processing: 9302-9552. End: 10104. Length of all words to process: 45460
# Processing: 29010-29260. End: 30312. Length of all words to process: 45460
# Processing: 19156-19406. End: 20208. Length of all words to process: 45460
# Processing: 34062-34312. End: 35364. Length of all words to process: 45460
# Processing: 4500-4750. End: 5052. Length of all words to process: 45460
# Processing: 24208-24458. End: 25260. Length of all words to process: 45460
# Processing: 14354-14604. End: 15156. Length of all words to process: 45460
# Processing: 39114-39364. End: 40416. Length of all words to process: 45460
# Processing: 44166-44416. End: 45460. Length of all words to process: 45460
# Processing: 9552-9802. End: 10104. Length of all words to process: 45460
# Processing: 29260-29510. End: 30312. Length of all words to process: 45460
# Processing: 19406-19656. End: 20208. Length of all words to process: 45460
# Processing: 34312-34562. End: 35364. Length of all words to process: 45460
# Processing: 4750-5000. End: 5052. Length of all words to process: 45460
# Processing: 24458-24708. End: 25260. Length of all words to process: 45460
# Processing: 14604-14854. End: 15156. Length of all words to process: 45460
# Processing: 39364-39614. End: 40416. Length of all words to process: 45460
# Processing: 44416-44666. End: 45460. Length of all words to process: 45460
# Processing: 9802-10052. End: 10104. Length of all words to process: 45460
# Processing: 29510-29760. End: 30312. Length of all words to process: 45460
# Processing: 19656-19906. End: 20208. Length of all words to process: 45460
# Processing: 34562-34812. End: 35364. Length of all words to process: 45460
# Processing: 5000-5052. End: 5052. Length of all words to process: 45460
# Finished processing: 0-5052
# Processing: 24708-24958. End: 25260. Length of all words to process: 45460
# Processing: 14854-15104. End: 15156. Length of all words to process: 45460
# Processing: 39614-39864. End: 40416. Length of all words to process: 45460
# Processing: 44666-44916. End: 45460. Length of all words to process: 45460
# Processing: 10052-10104. End: 10104. Length of all words to process: 45460
# Processing: 29760-30010. End: 30312. Length of all words to process: 45460
# Processing: 19906-20156. End: 20208. Length of all words to process: 45460
# Finished processing: 5052-10104
# Processing: 34812-35062. End: 35364. Length of all words to process: 45460
# Processing: 24958-25208. End: 25260. Length of all words to process: 45460
# Processing: 15104-15156. End: 15156. Length of all words to process: 45460
# Processing: 39864-40114. End: 40416. Length of all words to process: 45460
# Processing: 44916-45166. End: 45460. Length of all words to process: 45460
# Finished processing: 10104-15156
# Processing: 30010-30260. End: 30312. Length of all words to process: 45460
# Processing: 20156-20208. End: 20208. Length of all words to process: 45460
# Finished processing: 15156-20208
# Processing: 35062-35312. End: 35364. Length of all words to process: 45460
# Processing: 25208-25260. End: 25260. Length of all words to process: 45460
# Processing: 40114-40364. End: 40416. Length of all words to process: 45460
# Finished processing: 20208-25260
# Processing: 45166-45416. End: 45460. Length of all words to process: 45460
# Processing: 30260-30312. End: 30312. Length of all words to process: 45460
# Finished processing: 25260-30312
# Processing: 35312-35364. End: 35364. Length of all words to process: 45460
# Finished processing: 30312-35364
# Processing: 40364-40416. End: 40416. Length of all words to process: 45460
# Processing: 45416-45460. End: 45460. Length of all words to process: 45460
# Finished processing: 35364-40416
# Finished processing: 40416-45460

# %%
len(cache)
# Out:
# 9577841

# %%
with h5py.File(FILENAME_TRAIN, 'r') as hf:
    X_train_masked_words = hf["masked_words"]
    X_train_guesses = hf["previous_guesses"]
    y_train = hf['next_guess_probs']

    assert X_train_masked_words.shape[0] == X_train_guesses.shape[0] == y_train.shape[0]
    LEN_TRAIN = y_train.shape[0]
    print(f"Number of training samples and labels: {LEN_TRAIN}")
# Out:
# Number of training samples and labels: 7665680

# %%
with h5py.File(FILENAME_VAL, 'r') as hf:
    X_val_masked_words = hf["masked_words"]
    X_val_guesses = hf["previous_guesses"]
    y_val = hf['next_guess_probs']

    assert X_val_masked_words.shape[0] == X_val_guesses.shape[0] == y_val.shape[0]
    LEN_VAL = y_val.shape[0]
    print(f"Number of validation samples and labels: {LEN_VAL}")
# Out:
# Number of validation samples and labels: 1912161

# %% [markdown]
# We have 7,665,680 training and 1,912,161 validation samples and labels.
#
# In total: 9,577,841

# %% [markdown]
# ## Post processing
#
# - replace masked_word padding with -1
# - apply smoothing to labels
# - shuffle data

# %%
def update_h5_dataset(
    filename: str,
    masked_words: np.ndarray,
    previous_guesses: np.ndarray,
    next_guess_probs: np.ndarray,
):
    """Create or update an h5 dataset with new samples and labels. Save the dataset in chunks for faster access in batches."""
    with h5py.File(filename, "a") as hf:
        if "masked_words" in hf and "previous_guesses" in hf and "next_guess_probs" in hf:
            hf["masked_words"].resize((hf["masked_words"].shape[0] + masked_words.shape[0]), axis=0)
            hf["masked_words"][-masked_words.shape[0]:] = masked_words

            hf["previous_guesses"].resize((hf["previous_guesses"].shape[0] + previous_guesses.shape[0]), axis=0)
            hf["previous_guesses"][-previous_guesses.shape[0]:] = previous_guesses

            hf["next_guess_probs"].resize((hf["next_guess_probs"].shape[0] + next_guess_probs.shape[0]), axis=0)
            hf["next_guess_probs"][-next_guess_probs.shape[0]:] = next_guess_probs
        else:
            hf.create_dataset("masked_words", data=masked_words, maxshape=(None, *masked_words.shape[1:]), compression="gzip", compression_opts=2)
            hf.create_dataset("previous_guesses", data=previous_guesses, maxshape=(None, *previous_guesses.shape[1:]), compression="gzip", compression_opts=2)
            hf.create_dataset("next_guess_probs", data=next_guess_probs, maxshape=(None, *next_guess_probs.shape[1:]), compression="gzip", compression_opts=2)

# %%
SMOOTHING_FACTOR = 0.01


def replace_padding_with_minus_one(masked_words: np.ndarray) -> np.ndarray:
    row_sums = np.sum(masked_words, axis=2)
    masked_words[row_sums == 0] = -1
    return masked_words


def apply_smoothing(labels: np.ndarray, smoothing_factor: float) -> np.ndarray:
    return (labels + smoothing_factor) / (1 + smoothing_factor * labels.shape[1])

# %%
### train data

# %%
with h5py.File(FILENAME_TRAIN, 'r') as hf:
    X_train_masked_words = hf["masked_words"][:]
    X_train_guesses = hf["previous_guesses"][:]
    y_train = hf['next_guess_probs'][:]

    assert X_train_masked_words.shape[0] == X_train_guesses.shape[0] == y_train.shape[0]
    LEN_TRAIN = y_train.shape[0]
    print(f"Number of training samples and labels: {LEN_TRAIN}")
# Out:
# Number of training samples and labels: 7665680

# %%
X_train_masked_words = replace_padding_with_minus_one(X_train_masked_words)
y_train = apply_smoothing(y_train, SMOOTHING_FACTOR)

# %%
indices = np.arange(LEN_TRAIN)
np.random.shuffle(indices)

X_train_masked_words = X_train_masked_words[indices]
X_train_guesses = X_train_guesses[indices]
y_train = y_train[indices]

# %%
FILENAME_TRAIN_POST= "./data/train_data_post.h5"
batch_size = 250

for i in range(0, LEN_TRAIN, batch_size):
    masked_words = X_train_masked_words[i:i+batch_size]
    previous_guesses = X_train_guesses[i:i+batch_size]
    next_guess_probs = y_train[i:i+batch_size]
    update_h5_dataset(FILENAME_TRAIN_POST, masked_words, previous_guesses, next_guess_probs)

# %%
### validation data

# %%
with h5py.File(FILENAME_VAL, 'r') as hf:
    X_val_masked_words = hf["masked_words"][:]
    X_val_guesses = hf["previous_guesses"][:]
    y_val = hf['next_guess_probs'][:]

    assert X_val_masked_words.shape[0] == X_val_guesses.shape[0] == y_val.shape[0]
    LEN_VAL = y_val.shape[0]
    print(f"Number of validation samples and labels: {LEN_VAL}")
# Out:
# Number of validation samples and labels: 1912161

# %%
X_val_masked_words = replace_padding_with_minus_one(X_val_masked_words)
y_val = apply_smoothing(y_val, SMOOTHING_FACTOR)

# %%
# Shuffle the validation data
indices = np.arange(LEN_VAL)
np.random.shuffle(indices)

X_val_masked_words = X_val_masked_words[indices]
X_val_guesses = X_val_guesses[indices]
y_val = y_val[indices]

# %%
FILENAME_VAL_POST= "./data/validation_data_post.h5"
batch_size = 250

for i in range(0, LEN_VAL, batch_size):
    masked_words = X_val_masked_words[i:i+batch_size]
    previous_guesses = X_val_guesses[i:i+batch_size]
    next_guess_probs = y_val[i:i+batch_size]
    update_h5_dataset(FILENAME_VAL_POST, masked_words, previous_guesses, next_guess_probs)
